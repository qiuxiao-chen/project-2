# %% [markdown]
# # CS 5830 Project 2
# #### Anny Chen, Zion Steiner
# **Question**: How is crime distributed about the city of Austin?

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from scipy import stats as stats
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Data prep

# %%
df = pd.read_csv('crime-housing-austin-2015.csv')
pd.set_option('display.max_columns', None) # display all the hiden columns

# %%
# Convert dollar and percent values to floats
for col in df.select_dtypes(include=['object']):
    if '$' in df[col].iloc[0] or '%' in df[col].iloc[0]:
        df[col] = df[col].str.replace('\$|%', '').astype('float')
        
# Convert zip codes to str
df['Zip_Code_Crime'] = df['Zip_Code_Crime'].fillna(-1).astype('int32').apply(str)
df['Zip_Code_Housing'] = df['Zip_Code_Housing'].fillna(-1).astype('int32').apply(str)

# Convert report date to datetime type
df['Report_Date'] = pd.to_datetime(df['Report_Date'])

# %%
# Impute missing data
num_subset = df.columns[14:]

for col in num_subset:
    # Zipcode specific imputation
    df[col].fillna(df.groupby('Zip_Code_Crime')[col].median(), inplace=True)
    # For cases where all data is missing from zipcode
    df[col].fillna(df[col].median(), inplace=True)

# %% [markdown]
# ### Dataset attributes

# %%
df.head()
# Out:
#          Key  Council_District       Highest_Offense_Desc  \
# 0  201510782               4.0  AGG ROBBERY/DEADLY WEAPON
# 1  201511231               4.0         ROBBERY BY ASSAULT
# 2  201511736               1.0      BURGLARY OF RESIDENCE
# 3  201511433               4.0      BURGLARY OF RESIDENCE
# 4  201511936               2.0      BURGLARY OF RESIDENCE
#
#   Highest_NIBRS_UCR_Offense_Description Report_Date                 Location  \
# 0                               Robbery    1-Jan-15     9001 N IH 35 SVRD NB
# 1                               Robbery    1-Jan-15  919 E KOENIG LN SVRD EB
# 2                              Burglary    1-Jan-15    12151 N IH 35 SVRD NB
# 3                              Burglary    1-Jan-15   1044 NORWOOD PARK BLVD
# 4                              Burglary    1-Jan-15     2413 BITTER CREEK DR
#
#   Clearance_Status Clearance_Date District Zip_Code_Crime  Census_Tract  \
# 0                N      28-Jan-15        E          78753         18.13
# 1                N      13-Jan-15        I          78751         21.05
# 2                N      13-Jan-15        E          78753         18.35
# 3                N       5-Jan-15        I          78753         18.13
# 4                N       7-Jan-15        F          78744         24.27
#
#    X_Coordinate  Y_Coordinate Zip_Code_Housing  Populationbelowpovertylevel  \
# 0     3130483.0    10102366.0            78753                         26.0
# 1     3124730.0    10090296.0            78751                         26.0
# 2     3135985.0    10117220.0            78753                         26.0
# 3     3129896.0    10096032.0            78753                         26.0
# 4     3110455.0    10039340.0            78744                         26.0
#
#    Medianhouseholdincome  Non-WhiteNon-HispanicorLatino  \
# 0                39593.0                           20.0
# 1                38624.0                           11.0
# 2                39593.0                           20.0
# 3                39593.0                           20.0
# 4                41056.0                            9.0
#
#    HispanicorLatinoofanyrace  Populationwithdisability  Unemployment  \
# 0                       60.0                      10.0           9.0
# 1                       14.0                       6.0           9.0
# 2                       60.0                      10.0           9.0
# 3                       60.0                      10.0           9.0
# 4                       77.0                       8.0           9.0
#
#    Largehouseholds(5+members)  Homesaffordabletopeopleearninglessthan$50000  \
# 0                        16.0                                          78.0
# 1                         2.0                                          11.0
# 2                        16.0                                          78.0
# 3                        16.0                                          78.0
# 4                        23.0                                          93.0
#
#    Rentalsaffordabletopeopleearninglessthan$25000  Rent-restrictedunits  \
# 0                                            14.0                  17.0
# 1                                            13.0                   1.0
# 2                                            14.0                  17.0
# 3                                            14.0                  17.0
# 4                                             7.0                  24.0
#
#    HousingChoiceVoucherholders  Medianrent  Medianhomevalue  \
# 0                          4.0       826.0         134900.0
# 1                          0.0       865.0         292200.0
# 2                          4.0       826.0         134900.0
# 3                          4.0       826.0         134900.0
# 4                          8.0       946.0         108100.0
#
#    Percentageofrentalunitsinpoorcondition  \
# 0                                     0.7
# 1                                     0.4
# 2                                     0.7
# 3                                     0.7
# 4                                     0.7
#
#    Percentchangeinnumberofhousingunits2000-2012  \
# 0                                          19.0
# 1                                           7.0
# 2                                          19.0
# 3                                          19.0
# 4                                          35.0
#
#    Ownerunitsaffordabletoaverageretail/serviceworker  \
# 0                                                8.0
# 1                                                0.0
# 2                                                8.0
# 3                                                8.0
# 4                                               13.0
#
#    Rentalunitsaffordabletoaverageretail/serviceworker  \
# 0                                               11.0
# 1                                                9.0
# 2                                               11.0
# 3                                               11.0
# 4                                                6.0
#
#    Rentalunitsaffordabletoaverageartist  Ownerunitsaffordabletoaverageartist  \
# 0                                  40.0                                 24.0
# 1                                  38.0                                  2.0
# 2                                  40.0                                 24.0
# 3                                  40.0                                 24.0
# 4                                  22.0                                 33.0
#
#    Rentalunitsaffordabletoaverageteacher  \
# 0                                   89.0
# 1                                   68.0
# 2                                   89.0
# 3                                   89.0
# 4                                   81.0
#
#    Ownerunitsaffordabletoaverageteacher  \
# 0                                  75.0
# 1                                  10.0
# 2                                  75.0
# 3                                  75.0
# 4                                  87.0
#
#    Rentalunitsaffordabletoaveragetechworker  \
# 0                                     100.0
# 1                                      97.0
# 2                                     100.0
# 3                                     100.0
# 4                                     100.0
#
#    Ownerunitsaffordabletoaveragetechworker  \
# 0                                     98.0
# 1                                     42.0
# 2                                     98.0
# 3                                     98.0
# 4                                    100.0
#
#    Changeinpercentageofpopulationbelowpoverty2000-2012  \
# 0                                              128.0
# 1                                               23.0
# 2                                              128.0
# 3                                              128.0
# 4                                               89.0
#
#    Changeinmedianrent2000-2012  Changeinmedianhomevalue2000-2012  \
# 0                         26.0                              40.0
# 1                         38.0                              97.0
# 2                         26.0                              40.0
# 3                         26.0                              40.0
# 4                         26.0                              44.0
#
#    Percentageofhomeswithin1/4-mioftransitstop  \
# 0                                        59.0
# 1                                        98.0
# 2                                        59.0
# 3                                        59.0
# 4                                        63.0
#
#    Averagemonthlytransportationcost  \
# 0                             708.0
# 1                             550.0
# 2                             708.0
# 3                             708.0
# 4                             708.0
#
#    Percentageofhousingandtransportationcoststhatistransportation-related
# 0                                               44.0
# 1                                               40.0
# 2                                               44.0
# 3                                               44.0
# 4                                               40.0

# %%
df.describe()
# Out:
#                 Key  Council_District  Census_Tract  X_Coordinate  \
# count  3.857300e+04      38401.000000  38414.000000  3.798100e+04
# mean   1.787442e+10          5.223458     72.426942  3.115612e+06
# std    1.564763e+10          2.805340    686.752321  1.508935e+04
# min    2.015103e+08          1.000000      1.010000  3.040396e+06
# 25%    2.015186e+10          3.000000     15.040000  3.106999e+06
# 50%    2.015500e+10          5.000000     18.230000  3.116494e+06
# 75%    2.015503e+10          8.000000     23.040000  3.126048e+06
# max    2.015153e+12         10.000000   9800.000000  3.164242e+06
#
#        Y_Coordinate  Populationbelowpovertylevel  Medianhouseholdincome  \
# count  3.798100e+04                 38573.000000           38573.000000
# mean   1.008005e+07                    23.127758           50106.504654
# std    2.857887e+04                    12.783794           20569.708287
# min    1.001173e+07                     1.000000           11917.000000
# 25%    1.005776e+07                    16.000000           39593.000000
# 50%    1.007645e+07                    24.000000           41869.000000
# 75%    1.010246e+07                    29.000000           65672.000000
# max    1.015923e+07                    66.000000          127726.000000
#
#        Non-WhiteNon-HispanicorLatino  HispanicorLatinoofanyrace  \
# count                   38573.000000               38573.000000
# mean                       15.955409                  38.582195
# std                         6.931326                  20.123794
# min                         4.000000                   5.000000
# 25%                        10.000000                  19.000000
# 50%                        16.000000                  40.000000
# 75%                        20.000000                  57.000000
# max                        36.000000                  77.000000
#
#        Populationwithdisability  Unemployment  Largehouseholds(5+members)  \
# count              38573.000000  38573.000000                38573.000000
# mean                   9.075027      8.283825                    8.654318
# std                    2.222245      2.428841                    6.143490
# min                    3.000000      3.000000                    0.000000
# 25%                    8.000000      7.000000                    3.000000
# 50%                    9.000000      9.000000                    8.000000
# 75%                   10.000000      9.000000                   10.000000
# max                   17.000000     16.000000                   28.000000
#
#        Homesaffordabletopeopleearninglessthan$50000  \
# count                                  38573.000000
# mean                                      39.352941
# std                                       28.689530
# min                                        0.000000
# 25%                                       13.000000
# 50%                                       33.000000
# 75%                                       71.000000
# max                                       93.000000
#
#        Rentalsaffordabletopeopleearninglessthan$25000  Rent-restrictedunits  \
# count                                    38573.000000          38573.000000
# mean                                        11.713712             12.108288
# std                                          8.407699             10.623743
# min                                          0.000000              0.000000
# 25%                                          7.000000              4.000000
# 50%                                         11.000000              9.000000
# 75%                                         14.000000             20.000000
# max                                         41.000000             47.000000
#
#        HousingChoiceVoucherholders    Medianrent  Medianhomevalue  \
# count                 38573.000000  38573.000000     38573.000000
# mean                      2.640837    973.702460    224535.063386
# std                       3.215489    198.827952    117192.304368
# min                       0.000000    639.000000     54400.000000
# 25%                       0.000000    835.000000    134900.000000
# 50%                       2.000000    940.000000    176500.000000
# 75%                       3.000000   1016.000000    303100.000000
# max                      20.000000   2000.000000    621900.000000
#
#        Percentageofrentalunitsinpoorcondition  \
# count                            38573.000000
# mean                                 0.699966
# std                                  0.457263
# min                                  0.000000
# 25%                                  0.400000
# 50%                                  0.700000
# 75%                                  0.800000
# max                                  2.200000
#
#        Percentchangeinnumberofhousingunits2000-2012  \
# count                                  38573.000000
# mean                                      28.938065
# std                                       37.219534
# min                                        1.000000
# 25%                                        9.000000
# 50%                                       18.000000
# 75%                                       32.000000
# max                                      239.000000
#
#        Ownerunitsaffordabletoaverageretail/serviceworker  \
# count                                       38573.000000
# mean                                            5.558785
# std                                             8.461156
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             8.000000
# max                                            50.000000
#
#        Rentalunitsaffordabletoaverageretail/serviceworker  \
# count                                       38573.000000
# mean                                            9.548492
# std                                             7.792232
# min                                             0.000000
# 25%                                             6.000000
# 50%                                             8.000000
# 75%                                            11.000000
# max                                            39.000000
#
#        Rentalunitsaffordabletoaverageartist  \
# count                          38573.000000
# mean                              28.506365
# std                               12.770160
# min                                0.000000
# 25%                               22.000000
# 50%                               26.000000
# 75%                               40.000000
# max                               76.000000
#
#        Ownerunitsaffordabletoaverageartist  \
# count                         38573.000000
# mean                             11.317061
# std                              13.236382
# min                               0.000000
# 25%                               2.000000
# 50%                               4.000000
# 75%                              23.000000
# max                              50.000000
#
#        Rentalunitsaffordabletoaverageteacher  \
# count                           38573.000000
# mean                               72.956109
# std                                15.434680
# min                                 8.000000
# 25%                                68.000000
# 50%                                76.000000
# 75%                                83.000000
# max                               100.000000
#
#        Ownerunitsaffordabletoaverageteacher  \
# count                          38573.000000
# mean                              36.761154
# std                               28.167187
# min                                0.000000
# 25%                               13.000000
# 50%                               28.000000
# 75%                               69.000000
# max                               87.000000
#
#        Rentalunitsaffordabletoaveragetechworker  \
# count                              38573.000000
# mean                                  98.166438
# std                                    3.242680
# min                                   71.000000
# 25%                                   99.000000
# 50%                                   99.000000
# 75%                                  100.000000
# max                                  100.000000
#
#        Ownerunitsaffordabletoaveragetechworker  \
# count                             38573.000000
# mean                                 72.232961
# std                                  28.664644
# min                                   6.000000
# 25%                                  45.000000
# 50%                                  86.000000
# 75%                                  96.000000
# max                                 100.000000
#
#        Changeinpercentageofpopulationbelowpoverty2000-2012  \
# count                                       38573.000000
# mean                                           83.558992
# std                                            82.080948
# min                                           -20.000000
# 25%                                            33.000000
# 50%                                            60.000000
# 75%                                           128.000000
# max                                          1242.000000
#
#        Changeinmedianrent2000-2012  Changeinmedianhomevalue2000-2012  \
# count                 38573.000000                      38573.000000
# mean                     36.278900                         74.775231
# std                      24.764306                         38.488378
# min                       0.000000                        -37.000000
# 25%                      25.000000                         49.000000
# 50%                      28.000000                         60.000000
# 75%                      40.000000                         93.000000
# max                     115.000000                        207.000000
#
#        Percentageofhomeswithin1/4-mioftransitstop  \
# count                                38573.000000
# mean                                    66.470847
# std                                     25.832978
# min                                      0.000000
# 25%                                     59.000000
# 50%                                     76.000000
# 75%                                     80.000000
# max                                    100.000000
#
#        Averagemonthlytransportationcost  \
# count                      38573.000000
# mean                         655.011511
# std                           81.802661
# min                          433.000000
# 25%                          629.000000
# 50%                          668.000000
# 75%                          708.000000
# max                          865.000000
#
#        Percentageofhousingandtransportationcoststhatistransportation-related
# count                                       38573.000000
# mean                                           37.815778
# std                                             5.733692
# min                                            23.000000
# 25%                                            35.000000
# 50%                                            40.000000
# 75%                                            43.000000
# max                                            47.000000

# %%
df.columns
# Out:
# Index(['Key', 'Council_District', 'Highest_Offense_Desc',
#        'Highest_NIBRS_UCR_Offense_Description', 'Report_Date', 'Location',
#        'Clearance_Status', 'Clearance_Date', 'District', 'Zip_Code_Crime',
#        'Census_Tract', 'X_Coordinate', 'Y_Coordinate', 'Zip_Code_Housing',
#        'Populationbelowpovertylevel', 'Medianhouseholdincome',
#        'Non-WhiteNon-HispanicorLatino', 'HispanicorLatinoofanyrace',
#        'Populationwithdisability', 'Unemployment',
#        'Largehouseholds(5+members)',
#        'Homesaffordabletopeopleearninglessthan$50000',
#        'Rentalsaffordabletopeopleearninglessthan$25000',
#        'Rent-restrictedunits', 'HousingChoiceVoucherholders', 'Medianrent',
#        'Medianhomevalue', 'Percentageofrentalunitsinpoorcondition',
#        'Percentchangeinnumberofhousingunits2000-2012',
#        'Ownerunitsaffordabletoaverageretail/serviceworker',
#        'Rentalunitsaffordabletoaverageretail/serviceworker',
#        'Rentalunitsaffordabletoaverageartist',
#        'Ownerunitsaffordabletoaverageartist',
#        'Rentalunitsaffordabletoaverageteacher',
#        'Ownerunitsaffordabletoaverageteacher',
#        'Rentalunitsaffordabletoaveragetechworker',
#        'Ownerunitsaffordabletoaveragetechworker',
#        'Changeinpercentageofpopulationbelowpoverty2000-2012',
#        'Changeinmedianrent2000-2012', 'Changeinmedianhomevalue2000-2012',
#        'Percentageofhomeswithin1/4-mioftransitstop',
#        'Averagemonthlytransportationcost',
#        'Percentageofhousingandtransportationcoststhatistransportation-related'],
#       dtype='object')

# %% [markdown]
# ### Identify correlations of interest

# %%
# Find high correlations
from itertools import combinations

num_subset = df.columns[14:]
df_subset = df[num_subset]
combs = combinations(df_subset.columns, 2)

corrs = []
for comb in combs:
    corr, pval = stats.pearsonr(df_subset[comb[0]], df_subset[comb[1]])
    if corr >= 0.4:
        corrs.append((comb, corr, pval))
        
corrs.sort(key=lambda x: x[1], reverse=True)

# %%
corrs
# Out:
# [(('Homesaffordabletopeopleearninglessthan$50000',
#    'Ownerunitsaffordabletoaverageteacher'),
#   0.9965572497330673,
#   0.0),
#  (('Rentalsaffordabletopeopleearninglessthan$25000',
#    'Rentalunitsaffordabletoaverageretail/serviceworker'),
#   0.9845496765025599,
#   0.0),
#  (('Ownerunitsaffordabletoaverageretail/serviceworker',
#    'Ownerunitsaffordabletoaverageartist'),
#   0.9408826613139141,
#   0.0),
#  (('Ownerunitsaffordabletoaverageartist',
#    'Ownerunitsaffordabletoaverageteacher'),
#   0.9293125008246047,
#   0.0),
#  (('Homesaffordabletopeopleearninglessthan$50000',
#    'Ownerunitsaffordabletoaverageartist'),
#   0.9050512428582561,
#   0.0),
#  (('Percentageofrentalunitsinpoorcondition',
#    'Rentalunitsaffordabletoaverageretail/serviceworker'),
#   0.8883487176867016,
#   0.0),
#  (('Rentalunitsaffordabletoaverageteacher',
#    'Rentalunitsaffordabletoaveragetechworker'),
#   0.8679726567930366,
#   0.0),
#  (('Rentalsaffordabletopeopleearninglessthan$25000',
#    'Percentageofrentalunitsinpoorcondition'),
#   0.8601703808905897,
#   0.0),
#  (('Largehouseholds(5+members)', 'HousingChoiceVoucherholders'),
#   0.8389150351334579,
#   0.0),
#  (('HispanicorLatinoofanyrace',
#    'Homesaffordabletopeopleearninglessthan$50000'),
#   0.8360459994661344,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Largehouseholds(5+members)'),
#   0.8256322203145174,
#   0.0),
#  (('Rentalsaffordabletopeopleearninglessthan$25000',
#    'Rentalunitsaffordabletoaverageartist'),
#   0.8235151886097181,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Ownerunitsaffordabletoaverageteacher'),
#   0.8150785292857419,
#   0.0),
#  (('Rent-restrictedunits', 'Percentageofrentalunitsinpoorcondition'),
#   0.8100081693422821,
#   0.0),
#  (('Homesaffordabletopeopleearninglessthan$50000',
#    'Ownerunitsaffordabletoaveragetechworker'),
#   0.8023793505480167,
#   0.0),
#  (('Ownerunitsaffordabletoaverageretail/serviceworker',
#    'Ownerunitsaffordabletoaverageteacher'),
#   0.7979736730821887,
#   0.0),
#  (('Rent-restrictedunits',
#    'Rentalunitsaffordabletoaverageretail/serviceworker'),
#   0.7841155716126843,
#   0.0),
#  (('Populationbelowpovertylevel', 'Unemployment'), 0.7812347141113413, 0.0),
#  (('Ownerunitsaffordabletoaverageteacher',
#    'Ownerunitsaffordabletoaveragetechworker'),
#   0.7706016031497464,
#   0.0),
#  (('Homesaffordabletopeopleearninglessthan$50000',
#    'Ownerunitsaffordabletoaverageretail/serviceworker'),
#   0.7673958190227624,
#   0.0),
#  (('Populationwithdisability', 'Percentageofrentalunitsinpoorcondition'),
#   0.7608866326514774,
#   0.0),
#  (('Largehouseholds(5+members)',
#    'Homesaffordabletopeopleearninglessthan$50000'),
#   0.7575879529687154,
#   0.0),
#  (('Rentalunitsaffordabletoaverageteacher',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.7559203437458207,
#   0.0),
#  (('Rentalsaffordabletopeopleearninglessthan$25000', 'Rent-restrictedunits'),
#   0.7498261391024277,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Ownerunitsaffordabletoaveragetechworker'),
#   0.7471628630375038,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Ownerunitsaffordabletoaverageartist'),
#   0.7434295215182274,
#   0.0),
#  (('Rentalunitsaffordabletoaverageretail/serviceworker',
#    'Changeinmedianhomevalue2000-2012'),
#   0.7347188426201711,
#   0.0),
#  (('Largehouseholds(5+members)', 'Ownerunitsaffordabletoaverageteacher'),
#   0.7327557597502536,
#   0.0),
#  (('Rentalunitsaffordabletoaverageretail/serviceworker',
#    'Rentalunitsaffordabletoaverageartist'),
#   0.7256511096049854,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Rent-restrictedunits'),
#   0.7165425977698501,
#   0.0),
#  (('Rentalunitsaffordabletoaverageartist',
#    'Rentalunitsaffordabletoaverageteacher'),
#   0.7162653741360632,
#   0.0),
#  (('Medianhouseholdincome', 'Medianhomevalue'), 0.7134974014925016, 0.0),
#  (('Rentalunitsaffordabletoaveragetechworker',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.7048164242410262,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Rentalunitsaffordabletoaverageteacher'),
#   0.7012647527054982,
#   0.0),
#  (('Ownerunitsaffordabletoaveragetechworker',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.6800795133440848,
#   0.0),
#  (('Rentalsaffordabletopeopleearninglessthan$25000',
#    'Changeinmedianhomevalue2000-2012'),
#   0.6764225416588762,
#   0.0),
#  (('Populationwithdisability',
#    'Rentalunitsaffordabletoaverageretail/serviceworker'),
#   0.6694786121227875,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'HousingChoiceVoucherholders'),
#   0.6647628472362329,
#   0.0),
#  (('Largehouseholds(5+members)', 'Ownerunitsaffordabletoaverageartist'),
#   0.6611702648172988,
#   0.0),
#  (('Medianrent', 'Percentchangeinnumberofhousingunits2000-2012'),
#   0.6591665620610377,
#   0.0),
#  (('Rent-restrictedunits', 'HousingChoiceVoucherholders'),
#   0.6564504065398508,
#   0.0),
#  (('Populationwithdisability',
#    'Rentalsaffordabletopeopleearninglessthan$25000'),
#   0.6542527974375208,
#   0.0),
#  (('HispanicorLatinoofanyrace',
#    'Ownerunitsaffordabletoaverageretail/serviceworker'),
#   0.6371470720239834,
#   0.0),
#  (('Homesaffordabletopeopleearninglessthan$50000',
#    'Rentalunitsaffordabletoaverageteacher'),
#   0.6361379491627792,
#   0.0),
#  (('Largehouseholds(5+members)', 'Ownerunitsaffordabletoaveragetechworker'),
#   0.6249616359623882,
#   0.0),
#  (('Rentalunitsaffordabletoaverageteacher',
#    'Ownerunitsaffordabletoaverageteacher'),
#   0.6249454586165001,
#   0.0),
#  (('Rentalunitsaffordabletoaverageteacher',
#    'Ownerunitsaffordabletoaveragetechworker'),
#   0.6233374897777336,
#   0.0),
#  (('Populationwithdisability', 'Rent-restrictedunits'),
#   0.6210800099897172,
#   0.0),
#  (('Populationbelowpovertylevel',
#    'Percentageofhomeswithin1/4-mioftransitstop'),
#   0.6073027747421818,
#   0.0),
#  (('HispanicorLatinoofanyrace',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.6065943596020332,
#   0.0),
#  (('Homesaffordabletopeopleearninglessthan$50000',
#    'HousingChoiceVoucherholders'),
#   0.6064534566612384,
#   0.0),
#  (('Medianhouseholdincome', 'Medianrent'), 0.6026418658712049, 0.0),
#  (('Largehouseholds(5+members)', 'Rent-restrictedunits'),
#   0.597492691051397,
#   0.0),
#  (('Largehouseholds(5+members)',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.5953250564447238,
#   0.0),
#  (('Percentageofrentalunitsinpoorcondition',
#    'Rentalunitsaffordabletoaverageartist'),
#   0.5919942760328898,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Rentalunitsaffordabletoaverageartist'),
#   0.5902243285240975,
#   0.0),
#  (('Averagemonthlytransportationcost',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.5893734676834201,
#   0.0),
#  (('Largehouseholds(5+members)', 'Averagemonthlytransportationcost'),
#   0.5878494760609498,
#   0.0),
#  (('Rentalunitsaffordabletoaveragetechworker',
#    'Ownerunitsaffordabletoaveragetechworker'),
#   0.5846179333539021,
#   0.0),
#  (('HousingChoiceVoucherholders', 'Ownerunitsaffordabletoaverageteacher'),
#   0.584165471696128,
#   0.0),
#  (('Ownerunitsaffordabletoaverageartist',
#    'Ownerunitsaffordabletoaveragetechworker'),
#   0.5840473433459538,
#   0.0),
#  (('Percentageofrentalunitsinpoorcondition',
#    'Changeinmedianhomevalue2000-2012'),
#   0.5836884118327129,
#   0.0),
#  (('Homesaffordabletopeopleearninglessthan$50000',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.5708526748095298,
#   0.0),
#  (('Medianrent', 'Changeinmedianrent2000-2012'), 0.5524489386974046, 0.0),
#  (('HispanicorLatinoofanyrace', 'Rentalunitsaffordabletoaveragetechworker'),
#   0.5469583887464035,
#   0.0),
#  (('Ownerunitsaffordabletoaverageteacher',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.5459561968694582,
#   0.0),
#  (('Non-WhiteNon-HispanicorLatino', 'Unemployment'), 0.5436991252917882, 0.0),
#  (('Unemployment', 'Percentageofhomeswithin1/4-mioftransitstop'),
#   0.5433024857701294,
#   0.0),
#  (('Populationbelowpovertylevel', 'Rentalunitsaffordabletoaverageartist'),
#   0.539489122601632,
#   0.0),
#  (('Rent-restrictedunits', 'Rentalunitsaffordabletoaverageartist'),
#   0.5385741153485868,
#   0.0),
#  (('HousingChoiceVoucherholders', 'Ownerunitsaffordabletoaverageartist'),
#   0.5361517585257259,
#   0.0),
#  (('Populationwithdisability', 'Rentalunitsaffordabletoaverageartist'),
#   0.5344188915258701,
#   0.0),
#  (('Ownerunitsaffordabletoaverageartist',
#    'Rentalunitsaffordabletoaverageteacher'),
#   0.5343937725216555,
#   0.0),
#  (('Medianrent', 'Medianhomevalue'), 0.5293082851609753, 0.0),
#  (('Rentalunitsaffordabletoaverageartist',
#    'Percentageofhomeswithin1/4-mioftransitstop'),
#   0.5288593309748849,
#   0.0),
#  (('Rentalsaffordabletopeopleearninglessthan$25000',
#    'Percentageofhomeswithin1/4-mioftransitstop'),
#   0.5253682971158077,
#   0.0),
#  (('HousingChoiceVoucherholders', 'Ownerunitsaffordabletoaveragetechworker'),
#   0.522349293440946,
#   0.0),
#  (('Changeinmedianrent2000-2012',
#    'Percentageofhomeswithin1/4-mioftransitstop'),
#   0.5176299827476167,
#   0.0),
#  (('Largehouseholds(5+members)', 'Rentalunitsaffordabletoaverageteacher'),
#   0.5171089488538262,
#   0.0),
#  (('Unemployment', 'Rentalsaffordabletopeopleearninglessthan$25000'),
#   0.5162318985793614,
#   0.0),
#  (('Largehouseholds(5+members)',
#    'Ownerunitsaffordabletoaverageretail/serviceworker'),
#   0.511284094703728,
#   0.0),
#  (('Populationbelowpovertylevel', 'Ownerunitsaffordabletoaverageartist'),
#   0.5089776676509736,
#   0.0),
#  (('Changeinpercentageofpopulationbelowpoverty2000-2012',
#    'Averagemonthlytransportationcost'),
#   0.5047729915543196,
#   0.0),
#  (('Unemployment', 'Rentalunitsaffordabletoaverageartist'),
#   0.5027335438184,
#   0.0),
#  (('Unemployment', 'Percentageofrentalunitsinpoorcondition'),
#   0.4984914473377386,
#   0.0),
#  (('Rentalunitsaffordabletoaverageretail/serviceworker',
#    'Percentageofhomeswithin1/4-mioftransitstop'),
#   0.49603356148665384,
#   0.0),
#  (('Populationwithdisability', 'Changeinmedianhomevalue2000-2012'),
#   0.4949278073243508,
#   0.0),
#  (('Rent-restrictedunits', 'Ownerunitsaffordabletoaverageartist'),
#   0.4895781345783707,
#   0.0),
#  (('Ownerunitsaffordabletoaverageretail/serviceworker',
#    'Ownerunitsaffordabletoaveragetechworker'),
#   0.4884741266944527,
#   0.0),
#  (('Unemployment', 'Rent-restrictedunits'), 0.4870453016726801, 0.0),
#  (('Unemployment', 'Rentalunitsaffordabletoaverageretail/serviceworker'),
#   0.4867200653469818,
#   0.0),
#  (('Homesaffordabletopeopleearninglessthan$50000', 'Rent-restrictedunits'),
#   0.48447055735452665,
#   0.0),
#  (('Populationbelowpovertylevel', 'Ownerunitsaffordabletoaverageteacher'),
#   0.48095319819421045,
#   0.0),
#  (('HispanicorLatinoofanyrace',
#    'Rentalsaffordabletopeopleearninglessthan$25000'),
#   0.4789774866048205,
#   0.0),
#  (('Populationbelowpovertylevel',
#    'Rentalsaffordabletopeopleearninglessthan$25000'),
#   0.4771034536567296,
#   0.0),
#  (('Homesaffordabletopeopleearninglessthan$50000',
#    'Rentalunitsaffordabletoaveragetechworker'),
#   0.47634680053811806,
#   0.0),
#  (('Percentageofrentalunitsinpoorcondition',
#    'Percentageofhomeswithin1/4-mioftransitstop'),
#   0.4707667082548525,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Percentageofrentalunitsinpoorcondition'),
#   0.47012784894212634,
#   0.0),
#  (('Ownerunitsaffordabletoaverageretail/serviceworker',
#    'Rentalunitsaffordabletoaverageteacher'),
#   0.4687219359194319,
#   0.0),
#  (('Rent-restrictedunits', 'Ownerunitsaffordabletoaverageteacher'),
#   0.4670719490635666,
#   0.0),
#  (('Populationbelowpovertylevel',
#    'Homesaffordabletopeopleearninglessthan$50000'),
#   0.4666933078863992,
#   0.0),
#  (('Unemployment', 'Ownerunitsaffordabletoaveragetechworker'),
#   0.45823130723559713,
#   0.0),
#  (('HousingChoiceVoucherholders',
#    'Ownerunitsaffordabletoaverageretail/serviceworker'),
#   0.45718104079352645,
#   0.0),
#  (('Ownerunitsaffordabletoaverageteacher',
#    'Rentalunitsaffordabletoaveragetechworker'),
#   0.45434330979277554,
#   0.0),
#  (('Ownerunitsaffordabletoaverageartist',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.45305774574602414,
#   0.0),
#  (('HousingChoiceVoucherholders', 'Percentageofrentalunitsinpoorcondition'),
#   0.45236879451855044,
#   0.0),
#  (('Changeinpercentageofpopulationbelowpoverty2000-2012',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.4514755109810885,
#   0.0),
#  (('Populationbelowpovertylevel',
#    'Ownerunitsaffordabletoaverageretail/serviceworker'),
#   0.45063671328220084,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Unemployment'), 0.4494779133576537, 0.0),
#  (('Rentalunitsaffordabletoaveragetechworker',
#    'Averagemonthlytransportationcost'),
#   0.44725030702293067,
#   0.0),
#  (('Rent-restrictedunits', 'Rentalunitsaffordabletoaverageteacher'),
#   0.4444937111544525,
#   0.0),
#  (('Populationbelowpovertylevel', 'HispanicorLatinoofanyrace'),
#   0.4439155538129491,
#   0.0),
#  (('HousingChoiceVoucherholders',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.442704598901269,
#   0.0),
#  (('Rentalunitsaffordabletoaverageartist',
#    'Rentalunitsaffordabletoaveragetechworker'),
#   0.4423569941407577,
#   0.0),
#  (('Rent-restrictedunits',
#    'Ownerunitsaffordabletoaverageretail/serviceworker'),
#   0.44187910786556045,
#   0.0),
#  (('Percentchangeinnumberofhousingunits2000-2012',
#    'Changeinpercentageofpopulationbelowpoverty2000-2012'),
#   0.43976512312429233,
#   0.0),
#  (('Unemployment', 'Homesaffordabletopeopleearninglessthan$50000'),
#   0.4355665876853761,
#   0.0),
#  (('Populationbelowpovertylevel', 'Rent-restrictedunits'),
#   0.435460357382986,
#   0.0),
#  (('Rentalsaffordabletopeopleearninglessthan$25000',
#    'Rentalunitsaffordabletoaverageteacher'),
#   0.4348874115763136,
#   0.0),
#  (('HispanicorLatinoofanyrace',
#    'Rentalunitsaffordabletoaverageretail/serviceworker'),
#   0.43146272594114765,
#   0.0),
#  (('Unemployment', 'Ownerunitsaffordabletoaverageteacher'),
#   0.426310565572191,
#   0.0),
#  (('Populationbelowpovertylevel',
#    'Rentalunitsaffordabletoaverageretail/serviceworker'),
#   0.4258906125804068,
#   0.0),
#  (('HispanicorLatinoofanyrace', 'Populationwithdisability'),
#   0.42055391142874254,
#   0.0),
#  (('Rentalunitsaffordabletoaverageartist',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.41724177214870517,
#   0.0),
#  (('Rentalunitsaffordabletoaverageteacher',
#    'Averagemonthlytransportationcost'),
#   0.41480661073817526,
#   0.0),
#  (('Percentchangeinnumberofhousingunits2000-2012',
#    'Changeinmedianrent2000-2012'),
#   0.4147430292029637,
#   0.0),
#  (('HousingChoiceVoucherholders', 'Averagemonthlytransportationcost'),
#   0.41467842728287757,
#   0.0),
#  (('Ownerunitsaffordabletoaverageretail/serviceworker',
#    'Percentageofhousingandtransportationcoststhatistransportation-related'),
#   0.41401788728878086,
#   0.0),
#  (('Rent-restrictedunits', 'Changeinmedianhomevalue2000-2012'),
#   0.4038682599345114,
#   0.0),
#  (('Populationwithdisability', 'Percentageofhomeswithin1/4-mioftransitstop'),
#   0.4006111021723513,
#   0.0)]

# %% [markdown]
# ### Crime proportion by zip code

# %%
zip_code_crime_prop = pd.DataFrame(df['Zip_Code_Crime'].value_counts(normalize=True).reset_index())
zip_code_crime_prop.columns = ['Zip_Code_Crime', 'crime_prop']
df = pd.merge(df, zip_code_crime_prop, on='Zip_Code_Crime')
plt.title('Crime probability of each zip')
plt.bar(zip_code_crime_prop['Zip_Code_Crime'],zip_code_crime_prop['crime_prop'])
# Out:
# <BarContainer object of 48 artists>

# %%
# See what crime_prop is proportional to
display(df['crime_prop'].describe())
# Out:
# count    38573.000000
# mean         0.046828
# std          0.025235
# min          0.000026
# 25%          0.024032
# 50%          0.049802
# 75%          0.066445
# max          0.090011
# Name: crime_prop, dtype: float64

# %%
display(df.corr()['crime_prop'].sort_values(ascending=False))
display(df.corr()['Ownerunitsaffordabletoaverageteacher'].sort_values(ascending=False))
# Out:
# crime_prop                                                               1.000000
# Ownerunitsaffordabletoaverageteacher                                     0.540611
# Homesaffordabletopeopleearninglessthan$50000                             0.520392
# HispanicorLatinoofanyrace                                                0.518378
# Ownerunitsaffordabletoaverageartist                                      0.500552
# Ownerunitsaffordabletoaverageretail/serviceworker                        0.406896
# Rentalunitsaffordabletoaverageartist                                     0.388989
# Rentalunitsaffordabletoaverageteacher                                    0.376258
# Ownerunitsaffordabletoaveragetechworker                                  0.366587
# Percentageofhomeswithin1/4-mioftransitstop                               0.360431
# Rent-restrictedunits                                                     0.324227
# Populationbelowpovertylevel                                              0.320102
# X_Coordinate                                                             0.294396
# Populationwithdisability                                                 0.274309
# Unemployment                                                             0.243377
# Largehouseholds(5+members)                                               0.231656
# Rentalunitsaffordabletoaveragetechworker                                 0.226649
# Percentageofhousingandtransportationcoststhatistransportation-related    0.224260
# Rentalsaffordabletopeopleearninglessthan$25000                           0.209003
# Rentalunitsaffordabletoaverageretail/serviceworker                       0.183260
# Percentageofrentalunitsinpoorcondition                                   0.124386
# HousingChoiceVoucherholders                                              0.096979
# Changeinmedianrent2000-2012                                             -0.009880
# Non-WhiteNon-HispanicorLatino                                           -0.018954
# Key                                                                     -0.024252
# Averagemonthlytransportationcost                                        -0.067606
# Y_Coordinate                                                            -0.085729
# Changeinmedianhomevalue2000-2012                                        -0.089052
# Changeinpercentageofpopulationbelowpoverty2000-2012                     -0.101777
# Census_Tract                                                            -0.130458
# Percentchangeinnumberofhousingunits2000-2012                            -0.165739
# Council_District                                                        -0.248452
# Medianrent                                                              -0.251067
# Medianhomevalue                                                         -0.387767
# Medianhouseholdincome                                                   -0.401332
# Name: crime_prop, dtype: float64
# Ownerunitsaffordabletoaverageteacher                                     1.000000
# Homesaffordabletopeopleearninglessthan$50000                             0.996557
# Ownerunitsaffordabletoaverageartist                                      0.929313
# HispanicorLatinoofanyrace                                                0.815079
# Ownerunitsaffordabletoaverageretail/serviceworker                        0.797974
# Ownerunitsaffordabletoaveragetechworker                                  0.770602
# Largehouseholds(5+members)                                               0.732756
# Rentalunitsaffordabletoaverageteacher                                    0.624945
# HousingChoiceVoucherholders                                              0.584165
# Percentageofhousingandtransportationcoststhatistransportation-related    0.545956
# crime_prop                                                               0.540611
# X_Coordinate                                                             0.509326
# Populationbelowpovertylevel                                              0.480953
# Rent-restrictedunits                                                     0.467072
# Rentalunitsaffordabletoaveragetechworker                                 0.454343
# Unemployment                                                             0.426311
# Rentalunitsaffordabletoaverageartist                                     0.393381
# Non-WhiteNon-HispanicorLatino                                            0.319279
# Averagemonthlytransportationcost                                         0.316223
# Changeinpercentageofpopulationbelowpoverty2000-2012                      0.171775
# Percentageofrentalunitsinpoorcondition                                   0.136858
# Rentalsaffordabletopeopleearninglessthan$25000                           0.125540
# Populationwithdisability                                                 0.094641
# Percentageofhomeswithin1/4-mioftransitstop                               0.059967
# Rentalunitsaffordabletoaverageretail/serviceworker                       0.058630
# Y_Coordinate                                                             0.053271
# Key                                                                     -0.022321
# Census_Tract                                                            -0.024425
# Percentchangeinnumberofhousingunits2000-2012                            -0.186534
# Changeinmedianrent2000-2012                                             -0.306972
# Medianrent                                                              -0.456306
# Council_District                                                        -0.480902
# Changeinmedianhomevalue2000-2012                                        -0.485318
# Medianhouseholdincome                                                   -0.586663
# Medianhomevalue                                                         -0.712520
# Name: Ownerunitsaffordabletoaverageteacher, dtype: float64

# %%
print(f"Crime_prop - ownerunitsaffodablebyteachers: {stats.pearsonr(df['crime_prop'], df['Ownerunitsaffordabletoaverageteacher'])}")
print(f"crime_prop - X_coord: {stats.pearsonr(df['crime_prop'].fillna(method='ffill'), df['X_Coordinate'].fillna(method='ffill'))}")
# Out:
# Crime_prop - ownerunitsaffodablebyteachers: (0.5406107127788234, 0.0)
# crime_prop - X_coord: (0.2881715463888435, 0.0)

# %%
# Standardize crime_prop
mean = df['crime_prop'].mean()
std_dev = df['crime_prop'].std()
df['std_crime_prop'] = (df['crime_prop'] - mean) / std_dev

# %%
# Standardize household income
mean = df['Medianhouseholdincome'].mean()
std_dev = df['Medianhouseholdincome'].std()
df['std_income'] = (df['Medianhouseholdincome'] - mean) / std_dev

# Standardize Ownerunitsaffordabletoaverageteacher
mean = df['Ownerunitsaffordabletoaverageteacher'].mean()
std_dev = df['Ownerunitsaffordabletoaverageteacher'].std()
df['std_Ownerunitsaffordabletoaverageteacher'] = (df['Ownerunitsaffordabletoaverageteacher'] - mean) / std_dev


# Standardize Homesaffordabletopeopleearninglessthan$50000
mean = df['Homesaffordabletopeopleearninglessthan$50000'].mean()
std_dev = df['Homesaffordabletopeopleearninglessthan$50000'].std()
df['std_Homesaffordabletopeopleearninglessthan$50000'] = (df['Homesaffordabletopeopleearninglessthan$50000'] - mean) / std_dev

# %%
# Not normal but close enough
df['crime_prop'].plot.hist()

# %%
# Scatter plot of crime location
# plt.figure(figsize=(16, 16))
plt.figure(figsize=(16, 16))
plt.suptitle('Geographic Distribution of Crime', fontsize=20)
#sns.scatterplot(x='X_Coordinate', y='Y_Coordinate', hue='Highest_NIBRS_UCR_Offense_Description', data=df, ax=plt.subplot(221)).legend(loc='upper left')
#sns.scatterplot(x='X_Coordinate', y='Y_Coordinate', hue='Clearance_Status', data=df, ax=plt.subplot(222)).legend(loc='upper left')
ax1 = sns.scatterplot(x='X_Coordinate', y='Y_Coordinate', hue='std_crime_prop', data=df, ax=plt.subplot(221))
ax1.set_title('Standardized crime proportion by zip code', fontdict={'fontsize': 15})
ax1.legend(loc='upper left')
ax2 = sns.scatterplot(x='X_Coordinate', y='Y_Coordinate', hue='std_income', data=df, ax=plt.subplot(222))
ax2.set_title('Standardized median household income', fontdict={'fontsize': 15})
ax2.legend(loc='upper left')
ax3 = sns.scatterplot(x='X_Coordinate', y='Y_Coordinate', hue='std_Ownerunitsaffordabletoaverageteacher', data=df, ax=plt.subplot(223))
ax3.set_title('Standard Owner units affordable to average teacher', fontdict={'fontsize': 15})
ax3.legend(loc='upper left')
ax4 = sns.scatterplot(x='X_Coordinate', y='Y_Coordinate', hue='std_Homesaffordabletopeopleearninglessthan$50000', data=df, ax=plt.subplot(224))
ax4.set_title('Standard Homes affordable to people earning less than $50000', fontdict={'fontsize': 15})
ax4.legend(loc='upper left')

# plt.savefig('imgs/geoDistrCrime.png')
plt.show()

# %% [markdown]
# # T-TEST
# ### Question: Is crime more probable in the eastern half of the Austin?
# The graphs above show that crime was more common in the eastern regions of the city in 2015. Is there any statistical significance to this, or is this just due to chance?
#
# **Note**: This test would be more meaningful if this dataset contained only a sample of the crimes reported in Austin in 2015. Because we have all the data, we can actually answer this question definitively but we'll do this for exercise.
# ### Term definitions:
# * prob_crime_L: probability of a crime occuring west of X_Coordinate = 3100000
# * prob_crime_R: probability of a crime occuring east of X_Coordinate = 3100000
#
# ### Hypotheses:
# H_0: prob_crime_L == prob_crime_R
# H_a: prob_crime_R

# %%
crime_L = df.loc[df['X_Coordinate'] < 3.1e6]
crime_R = df.loc[df['X_Coordinate'] >= 3.1e6]

# %%
# Do they have equal variances?
print(crime_L['crime_prop'].std())
print(crime_R['crime_prop'].std())
# Close enough
# Out:
# 0.020746173599847435
# 0.024494558972252778

# %%
stats.ttest_ind(crime_L['crime_prop'], crime_R['crime_prop'])
# Out:
# Ttest_indResult(statistic=-62.00265755032987, pvalue=0.0)

# %%
sns.scatterplot(df['X_Coordinate'], df['crime_prop'])

# %% [markdown]
# # Crime Proportion by Date

# %%
data_code_crime_prop = pd.DataFrame(df['Report_Date'].value_counts(normalize=True).reset_index())
data_code_crime_prop.columns = ['Report_Date', 'crime_prop_data']
df = pd.merge(df, data_code_crime_prop, on='Report_Date')

# %%
df['crime_prop_data'].plot.hist()

# %%
plt.bar(df['Report_Date'],df['crime_prop_data'])
# Out:
# <BarContainer object of 38573 artists>

# %%
group_month = df.groupby( df.Report_Date.dt.month).count()
plt.bar(range(1,13),group_month['Key'])
# Out:
# <BarContainer object of 12 artists>
